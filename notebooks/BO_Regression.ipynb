# %%
# import xgboost
import pandas as pd
# from xgboost import XGBRegressor
import sklearn
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
import random
from sklearn.multioutput import MultiOutputRegressor
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, BayesianRidge
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import KFold
import pyDOE2
import optuna
from tqdm import tqdm
import datetime
import time

import tensorflow as tf


import sys
sys.path.append('../structural')
import load_data

import importlib
importlib.reload(load_data)
# Out:
# <module 'load_data' from 'C:\\Users\\Lyle\\Documents\\DeCoDE\\DeCoDE-Bike-Project-Git\\Structural Analysis\\load_data.py'>

# %%
x_scaled, y, _, xscaler = load_data.load_framed_dataset("r", onehot = True, scaled = True, augmented = True)

yscaler = StandardScaler()
yscaler.fit(y)
y_scaled = yscaler.transform(y)
# y_scaled=pd.DataFrame(y_scaled, columns=y.columns, index=y.index)
x_scaled=x_scaled.values

# %%
''' 
Outermost Function Call for hyperparameter tuning. 
Takes in dataframe of optimization parameters, datasets, parameter names, algorithm name
Takes in reduction parameter for Generalized Subspace Design for grid search (reduction)
Takes in the number of retrainings for each hyperparameter config (n_trials), number of Cross Val splits (n_splits),
number of iterations to run BO (n_bo) number of instantiations of the final hyperparameter configuration to test
First, we set up a wrapper function for the call to fit_bo that we can use with Optuna.
Nest, we set up the pruner and the study, then perform the initial grid sampling. 
We then reset the sampler for our study to the TPESampler and perform BO to find the best hyperparameter configuration
Finally, we call preparDF, saving a report, and search for an optimal instantiation of a model to return.
'''    
def hyperparam_search(df, function, xdata, ydata, indexnames, name, reduction=1, n_trials = 10, n_splits = 5, n_bo=100, n_inst=100, multi=False):
    def wrapper(trial): #Wrapper function for fit_bo
        return fit_bo(trial, function, df, xdata, ydata, n_trials, n_splits, multi)
    start_time = time.time()
    pruner = optuna.pruners.PercentilePruner(75.0, n_startup_trials=1, n_warmup_steps=3, interval_steps=1) #Pruner
    study = optuna.create_study(direction="maximize", pruner=pruner)  # Create a new study using pruner.
    n_configs = init_gridsample(study, wrapper, df, reduction=reduction) #Perform initial grid sampling
    study.sampler = optuna.samplers.TPESampler() #Set sampler to Tree-Structured Parzen Estimator
    study.optimize(wrapper, n_trials=n_bo) #Optimize
    bestparams = study.best_params
    prepareDF(df, bestparams, indexnames, name)
    model, r2, mse, mae = test_instantiations(function, bestparams, xdata, ydata, names, n_inst, multi)    
    save_results(name, n_configs, reduction, n_trials, n_splits, n_bo, n_inst, start_time, r2, mse, mae)
    return model




'''
Perform the initialization of the BO using grid sampling.
First call get_configlist to get the list of grid sampling configurations
Then for each configuration, initialize a single point grid sample search in optuna
Run 1 trial for each grid point
'''
def init_gridsample(study, func, df, reduction=5):
    configs=get_configlist(df, reduction) # Get the DOE configurations
    for config in configs: #Loop over all DOE configs
        
        #Create the search space
        search_space={}
        for i in range(len(df.index)):
            search_space[df.index[i]]=[config[i]]
            
        #Set the study's sampler to be single point gridsearch space, then do one round of fitting
        study.sampler=optuna.samplers.GridSampler(search_space) 
        study.optimize(func, n_trials=1)
    return len(configs)
        
        
'''
Calculate gridsearch configurations. If we have a reduction greater than one, use GSD to reduce
For each configuration, calculate the corresponding parameter values using get_gridvalm then return
'''
def get_configlist(df, reduction=5):
    #Create a list of the number of grid locations for parameter. 
    #Cont & int get 2 locations, Cat gets locations equal to # of discrete categories
    configsize=[]
    for parameter in df.index: 
        if df.loc[parameter, "Datatype"]=="Categorical":
            configsize.append(len(df.loc[parameter, "Values/Min-Max"]))
        else:
            configsize.append(df.loc[parameter, "Gridres"])
        
    print("Grid Dimensionality:" + str(configsize))
    
    #If reduction>1 we call gsd, otherwise do full fact
    if reduction>1:
        DOEconfigs=pyDOE2.gsd(configsize, reduction=reduction)
    else:
        DOEconfigs=pyDOE2.fullfact(configsize).astype(int)
    print("Number of GridSearch configs: " + str(len(DOEconfigs)))
    
    #Look up actual gridsearch values from indices
    configvals=[]
    for i in range(len(DOEconfigs)):
        newvals=[]
        for j in range(len(DOEconfigs[0])):
            newvals.append(get_gridval(df, df.index[j], DOEconfigs[i][j]))
        configvals.append(newvals)
    return configvals


'''
Calculate the value of a particular grid sampling point 
Categorical, continuous, and discrete variables are handled individually
Log scale our calculations when the variable is log scaled
We assume grid points are evenly spaced between limits 
'''
def get_gridval(df, parameter, index):
    #If categorical, we simply return the value corresponidng to the index
    if df.loc[parameter, "Datatype"]=="Categorical":
        return df.loc[parameter, "Values/Min-Max"][index]
    
    #Grab vals for minval, maxval and scaling from df for convenience
    minval=df.loc[parameter, "Values/Min-Max"][0]
    maxval=df.loc[parameter, "Values/Min-Max"][1]
    scaling=df.loc[parameter, "Logscaling"]
    gridres=df.loc[parameter, "Gridres"]
    
    #Calculate the percentile between the parameter limits to sample the grid point
    gridloc=index/gridres+1/gridres/2
    
    #scaling is true, we will logscale when performing our calculations
    if scaling==True:
        #Indices 0 and 1 should be at 25th and 75th percentile of parameter ranges, respecively
        value=np.exp((1-gridloc)*np.log(minval)+gridloc*np.log(maxval))
    else:
        value=(1-gridloc)*minval+gridloc*maxval
            
    #If we have an integer parameter, we round to the nearest integer
    if df.loc[parameter, "Datatype"]=="Continuous":
        return value
    if df.loc[parameter, "Datatype"]=="Integer":
        return round(value)


        
'''
Sample a particular parameter from the optuna trial. 
Automates the sampling call based on the information about the parameter contained in DF

This function duals as a simple dictionary lookup if trial is a dictionary. 
This allows the reuse of fit_XXX functions when selecting an instantiation for a given config
'''
def sample(trial, df, parameter):
    #If we have passed in a dictionary, simply index a value from the dictionary. 
    if type(trial)==dict:
        return trial.get(parameter)
    
    #We setup each call to the trial in the format Optuna expects. See the Optuna docs
    if df.loc[parameter, "Datatype"]=="Categorical":
        return trial.suggest_categorical(parameter, df.loc[parameter, "Values/Min-Max"])
    #Grab vals for minval, maxval and scaling from df for convenience
    minval=df.loc[parameter, "Values/Min-Max"][0]
    maxval=df.loc[parameter, "Values/Min-Max"][1]
    scaling=df.loc[parameter, "Logscaling"]
    if df.loc[parameter, "Datatype"]=="Continuous":
        return trial.suggest_float(parameter, minval, maxval, log=scaling)
    if df.loc[parameter, "Datatype"]=="Integer":
        return trial.suggest_int(parameter, minval, maxval, 1, log=scaling)

    
'''
General BO fit loop. For each trial in BO we will create n_trials k_fold splits where k is n_splits
This yields a total of n_trial*n_folds fitting runs. 
Since we apply the hyperparameters to each model differently, we call the func function, which is specified
This func function will be a unique function for each type of model which will assign the hyperparameters
The func function will then fit the model and return the model back. For each run, we score on the val set.
We pass intermediate scores in a report to Optuna so it can determine if the trial should be pruned
If the trial is pruned, the trial prematurely exits
'''
def fit_bo(trial, func, df, xdata, ydata, n_trials, n_splits, multi=False):
    valr2=0
    stepcount=0
    with tqdm(total=n_splits*n_trials) as pbar: #Progress bar
        for j in range(n_trials): 
            kf=KFold(n_splits=n_splits, random_state=None, shuffle=False)
            for train_index, test_index in kf.split(xdata): # for each trial, loop over k-fold split
                x_train, x_val = xdata[train_index], xdata[test_index]
                y_train, y_val = ydata[train_index], ydata[test_index]
                '''
                Define a variant of the fit_bo function that splits the data into many single objective problem. 
                This is necessary for certain regressors such as xgboost. Sklearn's multi-output regressor doesnt 
                support eval sets in the kwargs since it doesnt automatically split them into separate sets.
                See https://github.com/scikit-learn/scikit-learn/issues/15953#issuecomment-944909955
                '''
                if multi==False: #If multi-output regressor
                    model=func(trial, df, x_train, x_val, y_train, y_val) #Call the specified model init+fit function
                    valpreds = model.predict(x_val)
                else: #If single-output regressor
                    valpreds=np.zeros(np.shape(y_val))
                    trainpreds=np.zeros(np.shape(y_train))
                    for output in range(len(y_train[0,:])):
                        y_train_so = y_train[:,output].copy()
                        y_val_so = y_val[:,output].copy()
                        model= func(trial, df, x_train, x_val, y_train_so, y_val_so)
                        valpreds[:,output] = model.predict(x_val)
                instancer2 = sklearn.metrics.r2_score(y_val, valpreds)
                valr2+=instancer2
                trial.report(valr2/(stepcount+1), stepcount) #Report scores for potential early pruning
                if trial.should_prune(): #Exit if Optuna decides to prune
                    raise optuna.exceptions.TrialPruned()
                pbar.update(1) #Update progress bar
                stepcount+=1
        return valr2/n_splits/n_trials 
    
    

def plot_res(study): #Some Optuna plots
    optuna.visualization.matplotlib.plot_param_importances(study)
    optuna.visualization.matplotlib.plot_intermediate_values(study)
    optuna.visualization.matplotlib.plot_optimization_history(study)
    optuna.visualization.matplotlib.plot_slice(study)
    
    
'''
Select an optimal instantiation of a model. 
We have defined a constant random seed to ensure train and val sets across all models are consistent
numtest models are tested, all instantiated using bestparams. 
If sklearn-like is true, the class probabilities are given by predict_proba and predict returns classes
Otherwise, predict returns probabilities and we need to round to get the classes. 
We handle these cases separately. We report R2, MSE, and MAE. 
Simlarly to fit_bo, we need to handle regressors that only deal with single variable outputs. See above. 
'''
def test_instantiations(func, bestparams, xdata, ydata, names, numtest=100, multi=False):
    x_train, x_val, y_train, y_val = train_test_split(xdata, ydata, test_size=0.2, random_state=1)
    bestr2=float("-inf")
    for i in tqdm(range(numtest)):
        if multi==False: #If multi-output regressor
            model = func(bestparams, None, x_train, x_val, y_train, y_val, True)
            valpreds = model.predict(x_val)
            trainpreds = model.predict(x_train)
        else: #If single-output regressor
            valpreds=np.zeros(np.shape(y_val))
            trainpreds=np.zeros(np.shape(y_train))
            for output in range(len(y_train[0,:])):
                y_train_so = y_train[:,output].copy()
                y_val_so = y_val[:,output].copy()
                model= func(bestparams, None, x_train, x_val, y_train_so, y_val_so)
                valpreds[:,output] = model.predict(x_val)
                trainpreds[:,output] = model.predict(x_train)
        valr2 = sklearn.metrics.r2_score(y_val, valpreds)
        if valr2>bestr2: # If this model has the best R2 so far, store its train and val set predictions
            bestr2 = valr2
            bestmodel = model
            bestvalpreds=valpreds
            besttrainpreds=trainpreds
    #Calculate some metrics
    r2=sklearn.metrics.r2_score(y_val, bestvalpreds)
    mse=sklearn.metrics.mean_squared_error(y_val, bestvalpreds)
    mae=sklearn.metrics.mean_absolute_error(y_val, bestvalpreds)
    print("R2: " + str(r2))
    print("MSE: " + str(mse))
    print("MAE: " + str(mae))
    plotperf(y_train, besttrainpreds, y_val, bestvalpreds, names) #Scatterplots
    return model, r2, mse, mae



def plotperf(y_train, y_pred_train, y_val, y_pred_val, names): # Plot predictions vs target values
    fig = plt.figure(figsize=(36,14))
    plt.rcParams.update({'font.size': 18})
    size=14
    linewidth=4
    x_subplots=5
    y_subplots=2
    scales=[100,100,100,100,100,100,180/np.pi,1,1,1]
    units=["cm", "cm", "cm", "cm", "cm", "cm", "deg", "N/A", "N/A", "Kg"]
    for i in range(len(y_val[0,:])):
        scale=scales[i]
        ax = fig.add_subplot(y_subplots, x_subplots, i+1)
        np.partition(y_pred_val[:,i].flatten(), -2)[-10]
        minval = min([y_pred_val[:,i].min(), y_pred_train[:,i].min()])
        maxval = max([np.partition(y_pred_val[:,i].flatten(), -2)[-5], np.partition(y_pred_val[:,i].flatten(), -2)[-5]])
        plt.xlim([0, maxval*scale*1.1])
        plt.ylim([0, maxval*scale*1.1])
        plt.scatter(y_train[:,i]*scale, y_pred_train[:,i]*scale, c="#FFB000", s=size, label='Train Data')
        plt.scatter(y_val[:,i]*scale, y_pred_val[:,i]*scale, c="#DC267F", s=size, label='Val. Data')
        plt.legend(loc='upper left')
        plt.title(names[i] + " (" + units[i] + ")")
        ax=add_identity(ax)
        ax.set_xlabel("Simulated Value")
        ax.set_ylabel("Predicted Value")
    fig.tight_layout()

def add_identity(axes, *line_args, **line_kwargs): #Helper function to draw target line on plots
    identity, = axes.plot([], [], *line_args, **line_kwargs, c="#888888")
    def callback(axes):
        low_x, high_x = axes.get_xlim()
        low_y, high_y = axes.get_ylim()
        low = max(low_x, low_y)
        high = min(high_x, high_y)
        identity.set_data([low, high], [low, high])
    callback(axes)
    axes.callbacks.connect('xlim_changed', callback)
    axes.callbacks.connect('ylim_changed', callback)
    return axes

'''
Print out a clean(ish) report of hyperparameter configurations
'''
def prepareDF(df, bestparams, indexnames, name):
    df = df.copy()
    df.columns=["Datatype", "Values/[Min, Max]", "Log Scaling", "Gridpoint Count"]
    df["Best Value"] = bestparams.values()
    pd.options.display.float_format = '{:,.2f}'.format 
    for index in df.index:
        if df.at[index, "Datatype"]=="Integer":
            df.at[index, "Best Value"]=int(df.at[index, "Best Value"])
    df.index=indexnames
    df.columns.name = "Hyperparameter"
    df.to_csv("Results/" + name + "_Regression.csv", index_label="Hyperparameter")
    print(df)
    
'''
Open Report DF and update results
'''
def save_results(name, n_configs, reduction, n_trials, n_splits, n_bo, n_inst, start_time, r2, mse, mae):
    df=pd.read_csv("Results/regression_results.csv", index_col=0)
#     df=pd.DataFrame()
    df[name]=[n_configs, reduction, n_trials, n_splits, n_bo, n_inst, r2, mse, mae, time.time()-start_time, str(datetime.datetime.now())]
    df.index=["n_configs", "reduction", "n_trials", "n_splits", "n_bo", "n_inst", "Coefficient of Determination (R2)", "Mean Squared Error (MSE)", "Mean Absolute Error (MAE)", "Execution Time (s)", "Finish Time"]
    df.to_csv("Results/regression_results.csv")

# %% [markdown]
# **Neural Network**

# %%
def create_dnn(ddims, ydims, DO, layers, layersize, batchnorm, activation): #DNN Builder function
    model=tf.keras.Sequential()
    model.add(tf.keras.layers.InputLayer(input_shape=ddims))

    for i in range(layers): #Add a dense layer for each layer in range(layers)
        model.add(tf.keras.layers.Dense(layersize)) #Dense layer with size equal to layersize
        if batchnorm=="True": # Add batchnorm if true
            model.add(tf.keras.layers.BatchNormalization())
        if activation=="ReLU": # Add relu or Leaky ReLU
            model.add(tf.keras.layers.ReLU())
        if activation=="Leaky ReLU":
            model.add(tf.keras.layers.LeakyReLU())
        model.add(tf.keras.layers.Dropout(DO)) #Add dropout with strength equal to DO
    
    model.add(tf.keras.layers.Dense(ydims))
    return model

'''
Fit function for NNs. 
Dropout, layers, layersize, batchnorm, and activation are passed to our DNN builder, create_dnn
Patience, classweight, and lr are used in fitting.
Fit and return the model
'''
def fit_NN(trial_or_dict, df, x_train, x_val, y_train, y_val, inst=False):

    batchsize = sample(trial_or_dict, df, "batchsize")
    patience = sample(trial_or_dict, df, "patience")
    dropout = sample(trial_or_dict, df, "dropout")
    lr = sample(trial_or_dict, df, "lr")
    layers = sample(trial_or_dict, df, "layers")
    batchnorm = sample(trial_or_dict, df, "batchnorm")
    activation = sample(trial_or_dict, df, "activation")
    layersize = sample(trial_or_dict, df, "layersize")
    model=create_dnn(len(x_train[0,:]), len(y_train[0,:]), dropout, layers, layersize, batchnorm, activation)
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                          loss=tf.keras.losses.MeanSquaredError(),
                          metrics=['MSE'])
    model.fit(x=x_train, y=y_train, epochs=2000, batch_size=batchsize, validation_data=(x_val, y_val), callbacks=[callback], verbose=0)
    return model

#Create our dataframe of hyperparameters for NN fitting
df=pd.DataFrame()
df["batchsize"] = ["Integer", [32,1024], True, 2]
df["patience"] = ["Integer", [1,100], True, 2]
df["dropout"] = ["Continuous", [0.0,1.0], False, 2]
df["lr"] = ["Continuous", [1e-5, 0.1], True, 2]
df["layers"] = ["Integer", [1,6], False, 3]
df["batchnorm"] = ["Categorical", [False,True], False, "N/A"]
df["activation"] = ["Categorical", ["ReLU", "Leaky ReLU"], False, "N/A"]
df["layersize"] = ["Integer", [4,100], True, 3]
df = df.transpose()
df.columns=["Datatype", "Values/Min-Max", "Logscaling", "Gridres"]
NNdf = df

indexnames = ["Batch Size", "Early Stopping Patience", "Dropout Rate", "Learning Rate", "Number of Layers", "Include Batchnormalization", "Activation Function", "Layer Size"]
model = hyperparam_search(NNdf, fit_NN, x_scaled, y_scaled, indexnames, "NN", 5, 10, 5, 100, 100) #Find Hyperparams, save
# Out:
# [I 2022-08-30 08:21:16,969] A new study created in memory with name: no-name-80a8017a-a31d-4214-8511-4742b7f60c15
# Grid Dimensionality:[2, 2, 2, 2, 3, 2, 2, 3]
# Number of GridSearch configs: 100
#   0%|                                                                                           | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   0%|                                                                                           | 0/50 [00:19<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9068\1053226656.py in <cell line: 57>()
#      55
#      56 indexnames = ["Batch Size", "Early Stopping Patience", "Dropout Rate", "Learning Rate", "Number of Layers", "Include Batchnormalization", "Activation Function", "Layer Size"]
# ---> 57 model = hyperparam_search(NNdf, fit_NN, x_scaled, y_scaled, indexnames, "NN", 5, 10, 5, 100, 100) #Find Hyperparams, save
#
# ~\AppData\Local\Temp\ipykernel_9068\1954561907.py in hyperparam_search(df, function, xdata, ydata, indexnames, name, reduction, n_trials, n_splits, n_bo, n_inst, multi)
#      16     pruner = optuna.pruners.PercentilePruner(75.0, n_startup_trials=1, n_warmup_steps=3, interval_steps=1) #Pruner
#      17     study = optuna.create_study(direction="maximize", pruner=pruner)  # Create a new study using pruner.
# ---> 18     n_configs = init_gridsample(study, wrapper, df, reduction=reduction) #Perform initial grid sampling
#      19     study.sampler = optuna.samplers.TPESampler() #Set sampler to Tree-Structured Parzen Estimator
#      20     study.optimize(wrapper, n_trials=n_bo) #Optimize
#
# ~\AppData\Local\Temp\ipykernel_9068\1954561907.py in init_gridsample(study, func, df, reduction)
#      45         #Set the study's sampler to be single point gridsearch space, then do one round of fitting
#      46         study.sampler=optuna.samplers.GridSampler(search_space)
# ---> 47         study.optimize(func, n_trials=1)
#      48     return len(configs)
#      49
#
# ~\anaconda3\envs\tf\lib\site-packages\optuna\study\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     398             )
#     399
# --> 400         _optimize(
#     401             study=self,
#     402             func=func,
#
# ~\anaconda3\envs\tf\lib\site-packages\optuna\study\_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# ~\anaconda3\envs\tf\lib\site-packages\optuna\study\_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# ~\anaconda3\envs\tf\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# ~\AppData\Local\Temp\ipykernel_9068\1954561907.py in wrapper(trial)
#      12 def hyperparam_search(df, function, xdata, ydata, indexnames, name, reduction=1, n_trials = 10, n_splits = 5, n_bo=100, n_inst=100, multi=False):
#      13     def wrapper(trial): #Wrapper function for fit_bo
# ---> 14         return fit_bo(trial, function, df, xdata, ydata, n_trials, n_splits, multi)
#      15     start_time = time.time()
#      16     pruner = optuna.pruners.PercentilePruner(75.0, n_startup_trials=1, n_warmup_steps=3, interval_steps=1) #Pruner
#
# ~\AppData\Local\Temp\ipykernel_9068\1954561907.py in fit_bo(trial, func, df, xdata, ydata, n_trials, n_splits, multi)
#     167                 '''
#     168                 if multi==False: #If multi-output regressor
# --> 169                     model=func(trial, df, x_train, x_val, y_train, y_val) #Call the specified model init+fit function
#     170                     valpreds = model.predict(x_val)
#     171                 else: #If single-output regressor
#
# ~\AppData\Local\Temp\ipykernel_9068\1053226656.py in fit_NN(trial_or_dict, df, x_train, x_val, y_train, y_val, inst)
#      37                           loss=tf.keras.losses.MeanSquaredError(),
#      38                           metrics=['MSE'])
# ---> 39     model.fit(x=x_train, y=y_train, epochs=2000, batch_size=batchsize, validation_data=(x_val, y_val), callbacks=[callback], verbose=0)
#      40     return model
#      41
#
# ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1443                 model=self,
#    1444                 steps_per_execution=self._steps_per_execution)
# -> 1445           val_logs = self.evaluate(
#    1446               x=val_x,
#    1447               y=val_y,
#
# ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1754             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1755               callbacks.on_test_batch_begin(step)
# -> 1756               tmp_logs = self.test_function(iterator)
#    1757               if data_handler.should_sync:
#    1758                 context.async_wait()
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
tf.keras.models.save_model(model, "./Trained Models/BestNN_Regressor")

# %% [markdown]
# **XGBoost**

# %%
def fit_XGB(trial_or_dict, df, x_train, x_val, y_train, y_val, inst=False):
    depth = sample(trial_or_dict, df, "depth") #Max tree depth
    lamb = sample(trial_or_dict, df, "lamb") #L2 Regularization
    lr = sample(trial_or_dict, df, "lr") #eta in xgboost documentation (Learning rate)
    gamma = sample(trial_or_dict, df, "gamma")
    min_child_weight=sample(trial_or_dict, df, "min_child_weight")
    patience = sample(trial_or_dict, df, "patience")
    model = xgboost.XGBRegressor(eta=lr, reg_lambda=lamb, max_depth=depth, gamma=gamma, min_child_weight=min_child_weight)
    eval_set = [(x_val, y_val)]
    model.fit(x_train, y_train, eval_set=eval_set, verbose=0, early_stopping_rounds=patience)
    return model

#Create our dataframe of hyperparameters for XGB fitting
df=pd.DataFrame()
df["depth"] = ["Integer", [2,8], False, 3]
df["lamb"] = ["Continuous", [0.1,100], True, 3]
df["lr"] = ["Continuous", [0.0,1.0], False, 3]
df["gamma"] = ["Continuous", [0,1], False, 3]
df["min_child_weight"] = ["Continuous", [0.5,10], True, 3]
df["patience"] = ["Integer", [1,100], True, 3]
df = df.transpose()
df.columns=["Datatype", "Values/Min-Max", "Logscaling", "Gridres"]
XGBdf = df

indexnames = ["Maximum Tree Depth", "L2 Weight Regularization (lambda)", "Learning Rate (eta)", "Minimum Split Loss (gamma)", "Minimum Child Weight", "Early Stopping Patience"]
model = hyperparam_search(XGBdf, fit_XGB, x_scaled, y_scaled, indexnames, "XGB", 5, 10, 5, 100, 100, True) #Find Hyperparams, save
# Out:
# [I 2022-04-21 17:35:56,518] A new study created in memory with name: no-name-6e4331c0-25af-4987-b3b9-459707a4ef48
# Grid Dimensionality:[3, 3, 3, 3, 3, 3]
# Number of GridSearch configs: 148
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:43<00:00,  1.16it/s]
# [I 2022-04-21 17:36:39,857] Trial 0 finished with value: 0.3771013019986069 and parameters: {'depth': 3, 'lamb': 0.316227766016838, 'lr': 0.16666666666666666, 'gamma': 0.16666666666666666, 'min_child_weight': 0.8237744862210329, 'patience': 2}. Best is trial 0 with value: 0.3771013019986069.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:10<00:00,  1.42s/it]
# [I 2022-04-21 17:37:50,759] Trial 1 finished with value: 0.4987922790301214 and parameters: {'depth': 3, 'lamb': 0.316227766016838, 'lr': 0.16666666666666666, 'gamma': 0.16666666666666666, 'min_child_weight': 2.23606797749979, 'patience': 10}. Best is trial 1 with value: 0.4987922790301214.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:23<00:00,  1.66s/it]
# [I 2022-04-21 17:39:13,766] Trial 2 finished with value: 0.5279901700749847 and parameters: {'depth': 3, 'lamb': 0.316227766016838, 'lr': 0.16666666666666666, 'gamma': 0.16666666666666666, 'min_child_weight': 6.069622310029172, 'patience': 46}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:04<01:17,  1.65s/it]
# [I 2022-04-21 17:39:18,712] Trial 3 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:20<00:00,  1.61s/it]
# [I 2022-04-21 17:40:39,370] Trial 4 finished with value: 0.5003833578234069 and parameters: {'depth': 3, 'lamb': 0.316227766016838, 'lr': 0.16666666666666666, 'gamma': 0.5, 'min_child_weight': 2.23606797749979, 'patience': 46}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:09<02:24,  3.07s/it]
# [I 2022-04-21 17:40:48,582] Trial 5 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:02<00:46,  1.02it/s]
# [I 2022-04-21 17:40:51,526] Trial 6 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:05<01:19,  1.69s/it]
# [I 2022-04-21 17:40:56,610] Trial 7 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:04<01:18,  1.66s/it]
# [I 2022-04-21 17:41:01,608] Trial 8 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:15<00:00,  3.21it/s]
# [I 2022-04-21 17:41:17,165] Trial 9 finished with value: 0.4779631940730824 and parameters: {'depth': 3, 'lamb': 0.316227766016838, 'lr': 0.5, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 2}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:04<01:12,  1.54s/it]
# [I 2022-04-21 17:41:21,785] Trial 10 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:14,  3.32it/s]
# [I 2022-04-21 17:41:22,694] Trial 11 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:14,  3.31it/s]
# [I 2022-04-21 17:41:23,602] Trial 12 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:23<00:00,  2.16it/s]
# [I 2022-04-21 17:41:46,773] Trial 13 finished with value: 0.399158624157823 and parameters: {'depth': 3, 'lamb': 0.316227766016838, 'lr': 0.8333333333333333, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 10}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:12<00:00,  1.46s/it]
# [I 2022-04-21 17:42:59,664] Trial 14 finished with value: 0.4772112046622194 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.16666666666666666, 'gamma': 0.16666666666666666, 'min_child_weight': 0.8237744862210329, 'patience': 10}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:26<00:00,  1.73s/it]
# [I 2022-04-21 17:44:25,988] Trial 15 finished with value: 0.5075803530263693 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.16666666666666666, 'gamma': 0.16666666666666666, 'min_child_weight': 2.23606797749979, 'patience': 46}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:29<00:00,  1.78s/it]
# [I 2022-04-21 17:45:55,151] Trial 16 finished with value: 0.4790452013407188 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.16666666666666666, 'gamma': 0.5, 'min_child_weight': 0.8237744862210329, 'patience': 46}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:49<00:00,  1.01it/s]
# [I 2022-04-21 17:46:44,510] Trial 17 finished with value: 0.5174716454466414 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.16666666666666666, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 2}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:34<00:00,  1.89s/it]
# [I 2022-04-21 17:48:19,060] Trial 18 finished with value: 0.4642813534833765 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.5, 'gamma': 0.16666666666666666, 'min_child_weight': 0.8237744862210329, 'patience': 46}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:19<00:00,  2.54it/s]
# [I 2022-04-21 17:48:38,764] Trial 19 finished with value: 0.48870497854961503 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.5, 'gamma': 0.5, 'min_child_weight': 6.069622310029172, 'patience': 2}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:23,  2.02it/s]
# [I 2022-04-21 17:48:40,256] Trial 20 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:33<00:00,  1.47it/s]
# [I 2022-04-21 17:49:14,200] Trial 21 finished with value: 0.5021865385964815 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.5, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 10}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:16<00:00,  3.05it/s]
# [I 2022-04-21 17:49:30,576] Trial 22 finished with value: 0.4520928035073486 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.8333333333333333, 'gamma': 0.16666666666666666, 'min_child_weight': 6.069622310029172, 'patience': 2}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:18,  2.58it/s]
# [I 2022-04-21 17:49:31,741] Trial 23 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:28<00:00,  1.77it/s]
# [I 2022-04-21 17:49:59,925] Trial 24 finished with value: 0.47929532650873663 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.8333333333333333, 'gamma': 0.5, 'min_child_weight': 6.069622310029172, 'patience': 10}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:17,  2.67it/s]
# [I 2022-04-21 17:50:01,053] Trial 25 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:02<00:38,  1.21it/s]
# [I 2022-04-21 17:50:03,541] Trial 26 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:09<00:00,  1.40s/it]
# [I 2022-04-21 17:51:13,306] Trial 27 finished with value: 0.4798926591344034 and parameters: {'depth': 3, 'lamb': 3.1622776601683804, 'lr': 0.8333333333333333, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 46}. Best is trial 2 with value: 0.5279901700749847.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:46<00:00,  2.14s/it]
# [I 2022-04-21 17:53:00,122] Trial 28 finished with value: 0.5651103187050704 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.16666666666666666, 'gamma': 0.16666666666666666, 'min_child_weight': 0.8237744862210329, 'patience': 46}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:07<00:00,  1.36s/it]
# [I 2022-04-21 17:54:08,012] Trial 29 finished with value: 0.5533786504081005 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.16666666666666666, 'gamma': 0.5, 'min_child_weight': 6.069622310029172, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:15<00:00,  1.51s/it]
# [I 2022-04-21 17:55:23,468] Trial 30 finished with value: 0.5535349869388575 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.16666666666666666, 'gamma': 0.8333333333333333, 'min_child_weight': 2.23606797749979, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:27<00:00,  1.76s/it]
# [I 2022-04-21 17:56:51,394] Trial 31 finished with value: 0.5589101440275692 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.16666666666666666, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 10}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:34<00:00,  1.47it/s]
# [I 2022-04-21 17:57:25,519] Trial 32 finished with value: 0.5449628575877494 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.5, 'gamma': 0.16666666666666666, 'min_child_weight': 6.069622310029172, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:25<00:00,  1.99it/s]
# [I 2022-04-21 17:57:50,681] Trial 33 finished with value: 0.543986001661649 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.5, 'gamma': 0.5, 'min_child_weight': 2.23606797749979, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:44<00:00,  1.13it/s]
# [I 2022-04-21 17:58:34,769] Trial 34 finished with value: 0.5530334133822694 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.5, 'gamma': 0.5, 'min_child_weight': 6.069622310029172, 'patience': 10}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:24<00:00,  2.06it/s]
# [I 2022-04-21 17:58:59,062] Trial 35 finished with value: 0.5525936709337611 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.5, 'gamma': 0.8333333333333333, 'min_child_weight': 0.8237744862210329, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:40<00:00,  1.23it/s]
# [I 2022-04-21 17:59:39,570] Trial 36 finished with value: 0.5501833059732097 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.5, 'gamma': 0.8333333333333333, 'min_child_weight': 2.23606797749979, 'patience': 10}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:14<00:00,  1.49s/it]
# [I 2022-04-21 18:00:54,193] Trial 37 finished with value: 0.5528629676019251 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.5, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 46}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:22<00:00,  2.26it/s]
# [I 2022-04-21 18:01:16,345] Trial 38 finished with value: 0.529192240607619 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.8333333333333333, 'gamma': 0.16666666666666666, 'min_child_weight': 2.23606797749979, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:40<00:00,  1.25it/s]
# [I 2022-04-21 18:01:56,463] Trial 39 finished with value: 0.5439706031383749 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.8333333333333333, 'gamma': 0.16666666666666666, 'min_child_weight': 6.069622310029172, 'patience': 10}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:19<00:00,  2.57it/s]
# [I 2022-04-21 18:02:15,905] Trial 40 finished with value: 0.5369485280058182 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.8333333333333333, 'gamma': 0.5, 'min_child_weight': 0.8237744862210329, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:38<00:00,  1.29it/s]
# [I 2022-04-21 18:02:54,601] Trial 41 finished with value: 0.5393521423204636 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.8333333333333333, 'gamma': 0.5, 'min_child_weight': 2.23606797749979, 'patience': 10}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:12<00:00,  1.45s/it]
# [I 2022-04-21 18:04:06,910] Trial 42 finished with value: 0.5444813421761909 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.8333333333333333, 'gamma': 0.5, 'min_child_weight': 6.069622310029172, 'patience': 46}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:33<00:00,  1.49it/s]
# [I 2022-04-21 18:04:40,502] Trial 43 finished with value: 0.5428769312118886 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.8333333333333333, 'gamma': 0.8333333333333333, 'min_child_weight': 0.8237744862210329, 'patience': 10}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:09<00:00,  1.40s/it]
# [I 2022-04-21 18:05:50,463] Trial 44 finished with value: 0.537529623139257 and parameters: {'depth': 3, 'lamb': 31.62277660168379, 'lr': 0.8333333333333333, 'gamma': 0.8333333333333333, 'min_child_weight': 2.23606797749979, 'patience': 46}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:07<01:50,  2.35s/it]
# [I 2022-04-21 18:05:57,511] Trial 45 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [02:02<00:00,  2.45s/it]
# [I 2022-04-21 18:08:00,214] Trial 46 finished with value: 0.5133799217810419 and parameters: {'depth': 5, 'lamb': 0.316227766016838, 'lr': 0.16666666666666666, 'gamma': 0.16666666666666666, 'min_child_weight': 2.23606797749979, 'patience': 46}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:11<03:07,  3.99s/it]
# [I 2022-04-21 18:08:12,197] Trial 47 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:43<00:00,  1.16it/s]
# [I 2022-04-21 18:08:55,329] Trial 48 finished with value: 0.5237123019381377 and parameters: {'depth': 5, 'lamb': 0.316227766016838, 'lr': 0.16666666666666666, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:07<01:51,  2.37s/it]
# [I 2022-04-21 18:09:02,441] Trial 49 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:20<00:00,  2.46it/s]
# [I 2022-04-21 18:09:22,778] Trial 50 finished with value: 0.4898335207006744 and parameters: {'depth': 5, 'lamb': 0.316227766016838, 'lr': 0.5, 'gamma': 0.5, 'min_child_weight': 6.069622310029172, 'patience': 2}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:25,  1.87it/s]
# [I 2022-04-21 18:09:24,387] Trial 51 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:35<00:00,  1.39it/s]
# [I 2022-04-21 18:10:00,357] Trial 52 finished with value: 0.495213293677834 and parameters: {'depth': 5, 'lamb': 0.316227766016838, 'lr': 0.5, 'gamma': 0.8333333333333333, 'min_child_weight': 6.069622310029172, 'patience': 10}. Best is trial 28 with value: 0.5651103187050704.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# ...
# [I 2022-04-21 21:26:43,034] Trial 215 finished with value: 0.5963119943373343 and parameters: {'depth': 6, 'lamb': 83.31648836818545, 'lr': 0.2893491649723915, 'gamma': 0.20635033205245631, 'min_child_weight': 4.265307851473173, 'patience': 6}. Best is trial 211 with value: 0.5975739953196622.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:35<00:00,  1.90s/it]
# [I 2022-04-21 21:28:18,242] Trial 216 finished with value: 0.5945329968772546 and parameters: {'depth': 6, 'lamb': 82.52943398562091, 'lr': 0.29540648895215094, 'gamma': 0.20348738786130433, 'min_child_weight': 4.323604234608382, 'patience': 6}. Best is trial 211 with value: 0.5975739953196622.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:41<00:00,  2.02s/it]
# [I 2022-04-21 21:29:59,263] Trial 217 finished with value: 0.5966788916726034 and parameters: {'depth': 6, 'lamb': 82.26349863574305, 'lr': 0.2807520548495541, 'gamma': 0.12847523124039667, 'min_child_weight': 3.9911515898966656, 'patience': 6}. Best is trial 211 with value: 0.5975739953196622.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:32<00:00,  1.84s/it]
# [I 2022-04-21 21:31:31,429] Trial 218 finished with value: 0.5965742537776737 and parameters: {'depth': 6, 'lamb': 72.3366470549725, 'lr': 0.2852097390793238, 'gamma': 0.11979361977177307, 'min_child_weight': 4.004936924612777, 'patience': 6}. Best is trial 211 with value: 0.5975739953196622.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:34<00:00,  1.89s/it]
# [I 2022-04-21 21:33:06,028] Trial 219 finished with value: 0.5967402781187359 and parameters: {'depth': 6, 'lamb': 72.46692353756468, 'lr': 0.2834241742691559, 'gamma': 0.1049378337941128, 'min_child_weight': 4.041518958920874, 'patience': 6}. Best is trial 211 with value: 0.5975739953196622.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:31<00:00,  1.83s/it]
# [I 2022-04-21 21:34:37,516] Trial 220 finished with value: 0.5981011917543599 and parameters: {'depth': 6, 'lamb': 73.17494204379862, 'lr': 0.2853317542530315, 'gamma': 0.08449465458986889, 'min_child_weight': 3.989476320541658, 'patience': 6}. Best is trial 220 with value: 0.5981011917543599.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:33<00:00,  1.86s/it]
# [I 2022-04-21 21:36:10,675] Trial 221 finished with value: 0.5965814408501057 and parameters: {'depth': 6, 'lamb': 74.17482251372978, 'lr': 0.2861073802702305, 'gamma': 0.09114303263707231, 'min_child_weight': 4.026611285627401, 'patience': 6}. Best is trial 220 with value: 0.5981011917543599.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:32<00:00,  1.84s/it]
# [I 2022-04-21 21:37:42,715] Trial 222 finished with value: 0.5961740640506241 and parameters: {'depth': 6, 'lamb': 72.78349220208081, 'lr': 0.27946966783335014, 'gamma': 0.0955949346497767, 'min_child_weight': 4.007250810982038, 'patience': 6}. Best is trial 220 with value: 0.5981011917543599.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:38<00:00,  1.96s/it]
# [I 2022-04-21 21:39:20,796] Trial 223 finished with value: 0.5979366646156945 and parameters: {'depth': 6, 'lamb': 72.60217269937561, 'lr': 0.28227617474423883, 'gamma': 0.08401691274341766, 'min_child_weight': 4.020169813282432, 'patience': 6}. Best is trial 220 with value: 0.5981011917543599.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [02:48<00:00,  3.36s/it]
# [I 2022-04-21 21:42:08,954] Trial 224 finished with value: 0.5967406474305634 and parameters: {'depth': 6, 'lamb': 72.39628031517117, 'lr': 0.28008760223017404, 'gamma': 0.10261921371152431, 'min_child_weight': 5.017682971838727, 'patience': 8}. Best is trial 220 with value: 0.5981011917543599.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:40<00:00,  2.01s/it]
# [I 2022-04-21 21:43:49,448] Trial 225 finished with value: 0.5969463193225165 and parameters: {'depth': 6, 'lamb': 75.25877239691104, 'lr': 0.2802505359733055, 'gamma': 0.09988768155442675, 'min_child_weight': 4.801257041293293, 'patience': 8}. Best is trial 220 with value: 0.5981011917543599.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:36<00:00,  1.94s/it]
# [I 2022-04-21 21:45:26,369] Trial 226 finished with value: 0.5979340657343555 and parameters: {'depth': 6, 'lamb': 72.46960681725176, 'lr': 0.2759769548623428, 'gamma': 0.09903562218987709, 'min_child_weight': 4.968475032152511, 'patience': 8}. Best is trial 220 with value: 0.5981011917543599.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:56<00:00,  1.13s/it]
# [I 2022-04-21 21:46:23,011] Trial 227 finished with value: 0.5628090579444757 and parameters: {'depth': 6, 'lamb': 8.39697215502176, 'lr': 0.3564272874771758, 'gamma': 0.08947852769775079, 'min_child_weight': 4.9788018181072715, 'patience': 8}. Best is trial 220 with value: 0.5981011917543599.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:35<00:00,  1.91s/it]
# [I 2022-04-21 21:47:58,304] Trial 228 finished with value: 0.5987977432162784 and parameters: {'depth': 6, 'lamb': 72.41212385623335, 'lr': 0.2755418267297709, 'gamma': 0.0598182478351076, 'min_child_weight': 4.819112626419297, 'patience': 8}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:31<00:00,  1.84s/it]
# [I 2022-04-21 21:49:30,059] Trial 229 finished with value: 0.5967976520179028 and parameters: {'depth': 6, 'lamb': 70.92790588023281, 'lr': 0.2777175249234171, 'gamma': 0.05289268219912013, 'min_child_weight': 4.9617289286324615, 'patience': 8}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:32<00:00,  1.85s/it]
# [I 2022-04-21 21:51:02,733] Trial 230 finished with value: 0.5980323853143934 and parameters: {'depth': 6, 'lamb': 70.10980826609357, 'lr': 0.27517243542099795, 'gamma': 0.0653851428059631, 'min_child_weight': 4.9998885320224495, 'patience': 8}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:28<00:00,  1.76s/it]
# [I 2022-04-21 21:52:30,774] Trial 231 finished with value: 0.5955858043341558 and parameters: {'depth': 6, 'lamb': 71.67721913056234, 'lr': 0.2796143135794456, 'gamma': 0.05935195503005332, 'min_child_weight': 5.04507814057668, 'patience': 8}. Best is trial 228 with value: 0.5987977432162784.
#   6%|███████▌                                                                                                                       | 3/50 [00:04<01:12,  1.55s/it]
# [I 2022-04-21 21:52:35,435] Trial 232 pruned.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [02:07<00:00,  2.54s/it]
# [I 2022-04-21 21:54:42,599] Trial 233 finished with value: 0.595619384989887 and parameters: {'depth': 8, 'lamb': 68.22662296177096, 'lr': 0.2804882782000478, 'gamma': 0.07290610293838257, 'min_child_weight': 4.001331724235343, 'patience': 8}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:21<00:00,  1.64s/it]
# [I 2022-04-21 21:56:04,468] Trial 234 finished with value: 0.5948557276997676 and parameters: {'depth': 6, 'lamb': 71.06154719930294, 'lr': 0.29921376915131515, 'gamma': 0.029303871162761105, 'min_child_weight': 5.44869968125541, 'patience': 7}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:41<00:00,  2.03s/it]
# [I 2022-04-21 21:57:45,959] Trial 235 finished with value: 0.5981414853864221 and parameters: {'depth': 6, 'lamb': 71.03969045680115, 'lr': 0.2801465473468289, 'gamma': 0.12109248232908974, 'min_child_weight': 4.67728105801678, 'patience': 12}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:18<00:00,  1.56s/it]
# [I 2022-04-21 21:59:04,152] Trial 236 finished with value: 0.5928580913816865 and parameters: {'depth': 6, 'lamb': 73.26127115020631, 'lr': 0.39094411012213875, 'gamma': 0.1290371566497571, 'min_child_weight': 4.642002389596125, 'patience': 8}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:44<00:00,  2.08s/it]
# [I 2022-04-21 22:00:48,261] Trial 237 finished with value: 0.5964672279717622 and parameters: {'depth': 6, 'lamb': 67.78015181931065, 'lr': 0.27456486796396534, 'gamma': 0.1252807577388857, 'min_child_weight': 5.185185763674459, 'patience': 12}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:44<00:00,  2.08s/it]
# [I 2022-04-21 22:02:32,357] Trial 238 finished with value: 0.5982450094965908 and parameters: {'depth': 6, 'lamb': 75.57949592685961, 'lr': 0.2740362199768665, 'gamma': 0.10580731604977074, 'min_child_weight': 4.633720695255007, 'patience': 12}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:24<00:00,  1.69s/it]
# [I 2022-04-21 22:03:56,916] Trial 239 finished with value: 0.588881990566252 and parameters: {'depth': 4, 'lamb': 73.17036026274566, 'lr': 0.2715685963054234, 'gamma': 0.10643181695265162, 'min_child_weight': 5.486791628229679, 'patience': 15}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:41<00:00,  2.04s/it]
# [I 2022-04-21 22:05:38,753] Trial 240 finished with value: 0.5973701378380911 and parameters: {'depth': 6, 'lamb': 64.25918469427728, 'lr': 0.30390234212056955, 'gamma': 0.03765545850233305, 'min_child_weight': 4.541417188156281, 'patience': 12}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:48<00:00,  2.16s/it]
# [I 2022-04-21 22:07:26,985] Trial 241 finished with value: 0.5962346549896923 and parameters: {'depth': 6, 'lamb': 64.52316902334894, 'lr': 0.3061339982902771, 'gamma': 0.047213028217981325, 'min_child_weight': 4.581663720778632, 'patience': 12}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:40<00:00,  2.01s/it]
# [I 2022-04-21 22:09:07,377] Trial 242 finished with value: 0.5973053355125385 and parameters: {'depth': 6, 'lamb': 74.03631447815395, 'lr': 0.2713149472097107, 'gamma': 0.005855088171437164, 'min_child_weight': 4.5750205493526845, 'patience': 7}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:52<00:00,  2.24s/it]
# [I 2022-04-21 22:10:59,578] Trial 243 finished with value: 0.5968374655626859 and parameters: {'depth': 6, 'lamb': 74.96608151316691, 'lr': 0.2309676408282779, 'gamma': 0.03323964572907391, 'min_child_weight': 4.656353504178902, 'patience': 12}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:55<00:00,  2.30s/it]
# [I 2022-04-21 22:12:54,782] Trial 244 finished with value: 0.598401512181223 and parameters: {'depth': 6, 'lamb': 76.03940272386023, 'lr': 0.2337508134502817, 'gamma': 0.003987284188642672, 'min_child_weight': 4.6409711332949355, 'patience': 12}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:53<00:00,  2.28s/it]
# [I 2022-04-21 22:14:48,778] Trial 245 finished with value: 0.5968671088879729 and parameters: {'depth': 6, 'lamb': 64.88831963551459, 'lr': 0.2225678979664303, 'gamma': 0.006861120798578368, 'min_child_weight': 4.59673118833308, 'patience': 14}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:51<00:00,  2.24s/it]
# [I 2022-04-21 22:16:40,718] Trial 246 finished with value: 0.5958069797938108 and parameters: {'depth': 6, 'lamb': 53.116490608599875, 'lr': 0.22821612117827145, 'gamma': 0.010477331661371617, 'min_child_weight': 4.7644627316506085, 'patience': 15}. Best is trial 228 with value: 0.5987977432162784.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [03:27<00:00,  4.15s/it]
# [I 2022-04-21 22:20:08,325] Trial 247 finished with value: 0.5961154020014022 and parameters: {'depth': 6, 'lamb': 69.01470445807233, 'lr': 0.20121690337017914, 'gamma': 0.005161480476474002, 'min_child_weight': 5.43471028123002, 'patience': 13}. Best is trial 228 with value: 0.5987977432162784.
# Hyperparameter                       Datatype Values/[Min, Max] Log Scaling  \
# Maximum Tree Depth                    Integer            [2, 8]       False
# L2 Weight Regularization (lambda)  Continuous        [0.1, 100]        True
# Learning Rate (eta)                Continuous        [0.0, 1.0]       False
# Minimum Split Loss (gamma)         Continuous            [0, 1]       False
# Minimum Child Weight               Continuous         [0.5, 10]        True
# Early Stopping Patience               Integer          [1, 100]        True
#
# Hyperparameter                    Gridpoint Count  Best Value
# Maximum Tree Depth                              3        6.00
# L2 Weight Regularization (lambda)               3       72.41
# Learning Rate (eta)                             3        0.28
# Minimum Split Loss (gamma)                      3        0.06
# Minimum Child Weight                            3        4.82
# Early Stopping Patience                         3        8.00
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [03:20<00:00,  2.00s/it]
# R2: 0.5954326105760395
# MSE: 0.9775100309555302
# MAE: 0.20753658243689177

# %% [markdown]
# **KNeighbors**

# %%
def fit_KNN(trial_or_dict, df, x_train, x_val, y_train, y_val, inst=False):
    neighbors = sample(trial_or_dict, df, "neighbors")
    weights = sample(trial_or_dict, df, "weights")
    distances = sample(trial_or_dict, df, "distances")
    model = KNeighborsRegressor(n_neighbors=neighbors, 
                                 weights=weights, 
                                 metric=distances)
    model.fit(x_train, y_train)
    return model

#Create our dataframe of hyperparameters for KNN fitting
df=pd.DataFrame()
df["neighbors"] = ["Integer", [1,1000], True, 10]
df["weights"] = ["Categorical", ["uniform", "distance"], False, "N/A"]
df["distances"] = ["Categorical", ["euclidean", "manhattan", "chebyshev"], False, "N/A"]
df=df.transpose()
df.columns=["Datatype", "Values/Min-Max", "Logscaling", "Gridres"]
KNNdf=df


indexnames = ["Number of Neighbors", "Neighbor Weighting", "Distance Metric"]
model = hyperparam_search(KNNdf, fit_KNN, x_scaled, y_scaled, indexnames, "KNN", 1) #Find Hyperparams, save
# Out:
# [I 2022-04-21 17:27:27,574] A new study created in memory with name: no-name-9d02a53a-da7b-4b47-adce-941f2cf39ba3
# Grid Dimensionality:[10, 2, 3]
# Number of GridSearch configs: 60
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 42.99it/s]
# [I 2022-04-21 17:27:28,747] Trial 0 finished with value: -0.11528177520991953 and parameters: {'neighbors': 1, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 0 with value: -0.11528177520991953.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 32.83it/s]
# [I 2022-04-21 17:27:30,273] Trial 1 finished with value: -0.3716938626959398 and parameters: {'neighbors': 3, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 0 with value: -0.11528177520991953.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 23.28it/s]
# [I 2022-04-21 17:27:32,424] Trial 2 finished with value: 0.05308976809872211 and parameters: {'neighbors': 6, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 2 with value: 0.05308976809872211.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 23.10it/s]
# [I 2022-04-21 17:27:34,591] Trial 3 finished with value: 0.1924606786617812 and parameters: {'neighbors': 11, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 3 with value: 0.1924606786617812.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 22.73it/s]
# [I 2022-04-21 17:27:36,794] Trial 4 finished with value: 0.24880729568311027 and parameters: {'neighbors': 22, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 4 with value: 0.24880729568311027.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 21.61it/s]
# [I 2022-04-21 17:27:39,111] Trial 5 finished with value: 0.30678789789964755 and parameters: {'neighbors': 45, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 5 with value: 0.30678789789964755.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.02it/s]
# [I 2022-04-21 17:27:41,611] Trial 6 finished with value: 0.31168685038882915 and parameters: {'neighbors': 89, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 16.72it/s]
# [I 2022-04-21 17:27:44,604] Trial 7 finished with value: 0.29044565392506333 and parameters: {'neighbors': 178, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.72it/s]
# [I 2022-04-21 17:27:48,536] Trial 8 finished with value: 0.24838977536818135 and parameters: {'neighbors': 355, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.07it/s]
# [I 2022-04-21 17:27:54,053] Trial 9 finished with value: 0.18870360836056038 and parameters: {'neighbors': 708, 'weights': 'uniform', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:01, 29.39it/s]
# [I 2022-04-21 17:27:54,157] Trial 10 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 34.25it/s]
# [I 2022-04-21 17:27:55,620] Trial 11 finished with value: -0.28604720017118723 and parameters: {'neighbors': 3, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 23.04it/s]
# [I 2022-04-21 17:27:57,793] Trial 12 finished with value: 0.055293674681358165 and parameters: {'neighbors': 6, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 23.25it/s]
# [I 2022-04-21 17:27:59,947] Trial 13 finished with value: 0.17898175561643065 and parameters: {'neighbors': 11, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 22.95it/s]
# [I 2022-04-21 17:28:02,128] Trial 14 finished with value: 0.2530672937159427 and parameters: {'neighbors': 22, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 22.13it/s]
# [I 2022-04-21 17:28:04,390] Trial 15 finished with value: 0.3101209809675082 and parameters: {'neighbors': 45, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 6 with value: 0.31168685038882915.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.72it/s]
# [I 2022-04-21 17:28:06,805] Trial 16 finished with value: 0.31795270225223327 and parameters: {'neighbors': 89, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 16.36it/s]
# [I 2022-04-21 17:28:09,865] Trial 17 finished with value: 0.3002015775069203 and parameters: {'neighbors': 178, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.76it/s]
# [I 2022-04-21 17:28:14,119] Trial 18 finished with value: 0.2600041272916716 and parameters: {'neighbors': 355, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:06<00:00,  8.20it/s]
# [I 2022-04-21 17:28:20,223] Trial 19 finished with value: 0.20219229657765933 and parameters: {'neighbors': 708, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:03, 14.14it/s]
# [I 2022-04-21 17:28:20,438] Trial 20 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.50it/s]
# [I 2022-04-21 17:28:23,005] Trial 21 finished with value: -0.10125343218357578 and parameters: {'neighbors': 3, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 15.27it/s]
# [I 2022-04-21 17:28:26,283] Trial 22 finished with value: 0.15907344485475872 and parameters: {'neighbors': 6, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 15.12it/s]
# [I 2022-04-21 17:28:29,591] Trial 23 finished with value: 0.27744487963522596 and parameters: {'neighbors': 11, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 15.02it/s]
# [I 2022-04-21 17:28:32,923] Trial 24 finished with value: 0.26909641496907194 and parameters: {'neighbors': 22, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.65it/s]
# [I 2022-04-21 17:28:36,338] Trial 25 finished with value: 0.3103796631485177 and parameters: {'neighbors': 45, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.07it/s]
# [I 2022-04-21 17:28:39,892] Trial 26 finished with value: 0.3089177485791445 and parameters: {'neighbors': 89, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.61it/s]
# [I 2022-04-21 17:28:43,860] Trial 27 finished with value: 0.2833414017653214 and parameters: {'neighbors': 178, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.55it/s]
# [I 2022-04-21 17:28:48,603] Trial 28 finished with value: 0.24185976303251672 and parameters: {'neighbors': 355, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:06<00:00,  8.09it/s]
# [I 2022-04-21 17:28:54,787] Trial 29 finished with value: 0.1845929315023519 and parameters: {'neighbors': 708, 'weights': 'uniform', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:02, 16.47it/s]
# [I 2022-04-21 17:28:54,972] Trial 30 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.45it/s]
# [I 2022-04-21 17:28:57,545] Trial 31 finished with value: -0.08996856151192659 and parameters: {'neighbors': 3, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 15.29it/s]
# [I 2022-04-21 17:29:00,816] Trial 32 finished with value: 0.1599172116803891 and parameters: {'neighbors': 6, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 15.24it/s]
# [I 2022-04-21 17:29:04,099] Trial 33 finished with value: 0.25250329997958054 and parameters: {'neighbors': 11, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 15.01it/s]
# [I 2022-04-21 17:29:07,433] Trial 34 finished with value: 0.27723744269577255 and parameters: {'neighbors': 22, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.68it/s]
# [I 2022-04-21 17:29:10,841] Trial 35 finished with value: 0.3113161792503512 and parameters: {'neighbors': 45, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.08it/s]
# [I 2022-04-21 17:29:14,392] Trial 36 finished with value: 0.31605858532100817 and parameters: {'neighbors': 89, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.23it/s]
# [I 2022-04-21 17:29:18,482] Trial 37 finished with value: 0.2960194477314544 and parameters: {'neighbors': 178, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.15it/s]
# [I 2022-04-21 17:29:23,410] Trial 38 finished with value: 0.2576937699388061 and parameters: {'neighbors': 355, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:06<00:00,  7.64it/s]
# [I 2022-04-21 17:29:29,956] Trial 39 finished with value: 0.2031639020944238 and parameters: {'neighbors': 708, 'weights': 'distance', 'distances': 'manhattan'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:02, 17.48it/s]
# [I 2022-04-21 17:29:30,130] Trial 40 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:02, 15.69it/s]
# [I 2022-04-21 17:29:30,324] Trial 41 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:03, 12.70it/s]
# [I 2022-04-21 17:29:30,561] Trial 42 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 16.98it/s]
# [I 2022-04-21 17:29:33,508] Trial 43 finished with value: 0.06123402034061402 and parameters: {'neighbors': 11, 'weights': 'uniform', 'distances': 'chebyshev'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 16.66it/s]
# [I 2022-04-21 17:29:36,513] Trial 44 finished with value: 0.1900803499272446 and parameters: {'neighbors': 22, 'weights': 'uniform', 'distances': 'chebyshev'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 15.99it/s]
# [I 2022-04-21 17:29:39,642] Trial 45 finished with value: 0.2289737671883953 and parameters: {'neighbors': 45, 'weights': 'uniform', 'distances': 'chebyshev'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 15.34it/s]
# [I 2022-04-21 17:29:42,904] Trial 46 finished with value: 0.22415495068050695 and parameters: {'neighbors': 89, 'weights': 'uniform', 'distances': 'chebyshev'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.86it/s]
# [I 2022-04-21 17:29:46,514] Trial 47 finished with value: 0.18923744162780537 and parameters: {'neighbors': 178, 'weights': 'uniform', 'distances': 'chebyshev'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:05,  8.71it/s]
# [I 2022-04-21 17:29:46,860] Trial 48 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:06,  6.88it/s]
# [I 2022-04-21 17:29:47,299] Trial 49 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:02, 17.38it/s]
# [I 2022-04-21 17:29:47,474] Trial 50 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:02, 15.82it/s]
# [I 2022-04-21 17:29:47,666] Trial 51 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:03, 12.62it/s]
# [I 2022-04-21 17:29:47,906] Trial 52 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 16.67it/s]
# [I 2022-04-21 17:29:50,907] Trial 53 finished with value: 0.04961110186252971 and parameters: {'neighbors': 11, 'weights': 'distance', 'distances': 'chebyshev'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 16.62it/s]
# [I 2022-04-21 17:29:53,917] Trial 54 finished with value: 0.17917340763064543 and parameters: {'neighbors': 22, 'weights': 'distance', 'distances': 'chebyshev'}. Best is trial 16 with value: 0.31795270225223327.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 16.15it/s]
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 17.74it/s]
# [I 2022-04-21 17:32:45,867] Trial 119 finished with value: 0.31638963943111553 and parameters: {'neighbors': 98, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.02it/s]
# [I 2022-04-21 17:32:48,500] Trial 120 finished with value: 0.3108649479356714 and parameters: {'neighbors': 47, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.63it/s]
# [I 2022-04-21 17:32:51,051] Trial 121 finished with value: 0.3185353956256832 and parameters: {'neighbors': 69, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.79it/s]
# [I 2022-04-21 17:32:53,459] Trial 122 finished with value: 0.3150727807763644 and parameters: {'neighbors': 56, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.14it/s]
# [I 2022-04-21 17:32:55,945] Trial 123 finished with value: 0.31888415627972877 and parameters: {'neighbors': 74, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.24it/s]
# [I 2022-04-21 17:32:58,418] Trial 124 finished with value: 0.31888567798133843 and parameters: {'neighbors': 71, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.72it/s]
# [I 2022-04-21 17:33:00,955] Trial 125 finished with value: 0.31725679059546874 and parameters: {'neighbors': 93, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 18.36it/s]
# [I 2022-04-21 17:33:03,682] Trial 126 finished with value: 0.31138558037936315 and parameters: {'neighbors': 129, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 21.63it/s]
# [I 2022-04-21 17:33:05,997] Trial 127 finished with value: 0.3005851007252439 and parameters: {'neighbors': 36, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.53it/s]
# [I 2022-04-21 17:33:08,434] Trial 128 finished with value: 0.3185353956256832 and parameters: {'neighbors': 69, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 21.52it/s]
# [I 2022-04-21 17:33:10,761] Trial 129 finished with value: 0.3108649479356714 and parameters: {'neighbors': 47, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.67it/s]
# [I 2022-04-21 17:33:13,306] Trial 130 finished with value: 0.31618451006234877 and parameters: {'neighbors': 102, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.54it/s]
# [I 2022-04-21 17:33:15,744] Trial 131 finished with value: 0.3189325467394662 and parameters: {'neighbors': 72, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.72it/s]
# [I 2022-04-21 17:33:18,159] Trial 132 finished with value: 0.3167218016133671 and parameters: {'neighbors': 60, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.14it/s]
# [I 2022-04-21 17:33:20,773] Trial 133 finished with value: 0.31817423256187005 and parameters: {'neighbors': 87, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.06it/s]
# [I 2022-04-21 17:33:23,400] Trial 134 finished with value: 0.3189325467394662 and parameters: {'neighbors': 72, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:02, 22.54it/s]
# [I 2022-04-21 17:33:23,535] Trial 135 pruned.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 17.92it/s]
# [I 2022-04-21 17:33:26,332] Trial 136 finished with value: 0.3141055675492118 and parameters: {'neighbors': 112, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.84it/s]
# [I 2022-04-21 17:33:29,947] Trial 137 finished with value: 0.3170979686358886 and parameters: {'neighbors': 65, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.38it/s]
# [I 2022-04-21 17:33:33,428] Trial 138 finished with value: 0.308903596321917 and parameters: {'neighbors': 43, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.12it/s]
# [I 2022-04-21 17:33:35,918] Trial 139 finished with value: 0.31888567798133843 and parameters: {'neighbors': 71, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 21.04it/s]
# [I 2022-04-21 17:33:38,298] Trial 140 finished with value: 0.3120616368143031 and parameters: {'neighbors': 50, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.53it/s]
# [I 2022-04-21 17:33:40,735] Trial 141 finished with value: 0.31815310838614275 and parameters: {'neighbors': 68, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.68it/s]
# [I 2022-04-21 17:33:43,278] Trial 142 finished with value: 0.31812168636398497 and parameters: {'neighbors': 86, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.36it/s]
# [I 2022-04-21 17:33:45,736] Trial 143 finished with value: 0.3150727807763644 and parameters: {'neighbors': 56, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.75it/s]
# [I 2022-04-21 17:33:48,271] Trial 144 finished with value: 0.3187637196139609 and parameters: {'neighbors': 73, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.37it/s]
# [I 2022-04-21 17:33:50,854] Trial 145 finished with value: 0.31692784355767645 and parameters: {'neighbors': 96, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.58it/s]
# [I 2022-04-21 17:33:53,286] Trial 146 finished with value: 0.3156592554513396 and parameters: {'neighbors': 57, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 18.20it/s]
# [I 2022-04-21 17:33:56,036] Trial 147 finished with value: 0.3132267132124094 and parameters: {'neighbors': 121, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.12it/s]
# [I 2022-04-21 17:33:58,524] Trial 148 finished with value: 0.31888567798133843 and parameters: {'neighbors': 71, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 21.81it/s]
# [I 2022-04-21 17:34:00,819] Trial 149 finished with value: 0.2740324877641694 and parameters: {'neighbors': 27, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 18.03it/s]
# [I 2022-04-21 17:34:03,597] Trial 150 finished with value: 0.3172399158168041 and parameters: {'neighbors': 66, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 17.98it/s]
# [I 2022-04-21 17:34:06,382] Trial 151 finished with value: 0.31812168636398497 and parameters: {'neighbors': 86, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 18.09it/s]
# [I 2022-04-21 17:34:09,150] Trial 152 finished with value: 0.31888415627972877 and parameters: {'neighbors': 74, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 17.50it/s]
# [I 2022-04-21 17:34:12,011] Trial 153 finished with value: 0.31567926208885533 and parameters: {'neighbors': 103, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 18.28it/s]
# [I 2022-04-21 17:34:14,750] Trial 154 finished with value: 0.3165044727550643 and parameters: {'neighbors': 59, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 19.95it/s]
# [I 2022-04-21 17:34:17,259] Trial 155 finished with value: 0.31888567798133843 and parameters: {'neighbors': 71, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.97it/s]
# [I 2022-04-21 17:34:19,647] Trial 156 finished with value: 0.3067323982893457 and parameters: {'neighbors': 41, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.85it/s]
# [I 2022-04-21 17:34:22,047] Trial 157 finished with value: 0.31137445810458503 and parameters: {'neighbors': 49, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:05,  7.87it/s]
# [I 2022-04-21 17:34:22,431] Trial 158 pruned.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 20.34it/s]
# [I 2022-04-21 17:34:24,893] Trial 159 finished with value: 0.3184027549701346 and parameters: {'neighbors': 84, 'weights': 'distance', 'distances': 'euclidean'}. Best is trial 64 with value: 0.31897563501881593.
# Hyperparameter          Datatype                  Values/[Min, Max]  \
# Number of Neighbors      Integer                          [1, 1000]
# Neighbor Weighting   Categorical                [uniform, distance]
# Distance Metric      Categorical  [euclidean, manhattan, chebyshev]
#
# Hyperparameter      Log Scaling Gridpoint Count Best Value
# Number of Neighbors        True              10         70
# Neighbor Weighting        False             N/A   distance
# Distance Metric           False             N/A  euclidean
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:25<00:00,  3.89it/s]
# R2: 0.30611884042216364
# MSE: 1.2699605500312026
# MAE: 0.41151459164255544

# %% [markdown]
# **Decision Tree**

# %%
def fit_DT(trial_or_dict, df, x_train, x_val, y_train, y_val, inst=False):
    max_depth = sample(trial_or_dict, df, "max_depth")
    splitter = sample(trial_or_dict, df, "splitter")
    criterion = sample(trial_or_dict, df, "criterion")
    min_samples_split = sample(trial_or_dict, df, "min_samples_split")
    min_samples_leaf = sample(trial_or_dict, df, "min_samples_leaf")
    max_features = sample(trial_or_dict, df, "max_features")
    model = sklearn.tree.DecisionTreeRegressor(splitter=splitter, 
                            max_depth=max_depth, 
                            criterion=criterion,
                            min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            max_features=max_features,)
    model.fit(x_train, y_train)
    return model

#Create our dataframe of hyperparameters for SVM fitting
df=pd.DataFrame()
df["max_depth"] = ["Integer", [2,10], False, 5]
df["splitter"] = ["Categorical", ["best", "random"], False, "N/A"]
df["criterion"] = ["Categorical", ["squared_error","friedman_mse","absolute_error"], False, "N/A"]
df["min_samples_split"] = ["Integer", [2,20], True, 3]
df["min_samples_leaf"] = ["Integer", [1,20], True, 3]
df["max_features"] = ["Integer", [1,len(x_scaled[0])], True, 3]
df=df.transpose()
df.columns=["Datatype", "Values/Min-Max", "Logscaling", "Gridres"]
DTdf=df

indexnames=["Maximum Tree Depth", "Splitting Strategy", "Split Quality Criterion", "Min. Samples to Split Internal Node", "Min. Samples to Split Leaf Node", "Features Considered During Split"]
model = hyperparam_search(DTdf, fit_DT, x_scaled, y_scaled, indexnames, "DT", 5) #Find Hyperparams, save
# Out:
# [I 2022-04-23 14:41:24,201] A new study created in memory with name: no-name-9dcfe8c6-7121-4908-a36b-0e6de6ad2837
# Grid Dimensionality:[5, 2, 3, 3, 3, 3]
# Number of GridSearch configs: 162
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 283.37it/s]
# [I 2022-04-23 14:41:24,443] Trial 0 finished with value: 0.03720006304545606 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'squared_error', 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 2}. Best is trial 0 with value: 0.03720006304545606.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 209.03it/s]
# [I 2022-04-23 14:41:24,686] Trial 1 finished with value: 0.11100468029009325 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'squared_error', 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 6}. Best is trial 1 with value: 0.11100468029009325.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 107.43it/s]
# [I 2022-04-23 14:41:25,154] Trial 2 finished with value: 0.21561184036784686 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'squared_error', 'min_samples_split': 3, 'min_samples_leaf': 12, 'max_features': 21}. Best is trial 2 with value: 0.21561184036784686.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 208.59it/s]
# [I 2022-04-23 14:41:25,397] Trial 3 finished with value: 0.0394063158698561 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'squared_error', 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 6}. Best is trial 2 with value: 0.21561184036784686.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 105.95it/s]
# [I 2022-04-23 14:41:25,873] Trial 4 finished with value: 0.07188920652160749 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'squared_error', 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 21}. Best is trial 2 with value: 0.21561184036784686.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 105.17it/s]
# [I 2022-04-23 14:41:26,351] Trial 5 finished with value: 0.2237471102014807 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'squared_error', 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': 21}. Best is trial 5 with value: 0.2237471102014807.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 146.22it/s]
# [I 2022-04-23 14:41:26,375] Trial 6 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 105.95it/s]
# [I 2022-04-23 14:41:26,850] Trial 7 finished with value: 0.061200257897907284 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'friedman_mse', 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 21}. Best is trial 5 with value: 0.2237471102014807.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:00, 78.88it/s]
# [I 2022-04-23 14:41:26,891] Trial 8 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 286.29it/s]
# [I 2022-04-23 14:41:27,069] Trial 9 finished with value: 0.05819645538942553 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'friedman_mse', 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 2}. Best is trial 5 with value: 0.2237471102014807.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [03:01<00:00,  3.63s/it]
# [I 2022-04-23 14:44:28,580] Trial 10 finished with value: 0.25273894722900436 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 21}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:02<00:32,  1.44it/s]
# [I 2022-04-23 14:44:30,665] Trial 11 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:29,  1.58it/s]
# [I 2022-04-23 14:44:32,562] Trial 12 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:59<00:00,  1.20s/it]
# [I 2022-04-23 14:45:32,405] Trial 13 finished with value: 0.12808067241348992 and parameters: {'max_depth': 3, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 6}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 321.27it/s]
# [I 2022-04-23 14:45:32,564] Trial 14 finished with value: 0.10539289289976846 and parameters: {'max_depth': 3, 'splitter': 'random', 'criterion': 'squared_error', 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 6}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 269.31it/s]
# [I 2022-04-23 14:45:32,753] Trial 15 finished with value: 0.18262252105142843 and parameters: {'max_depth': 3, 'splitter': 'random', 'criterion': 'squared_error', 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 21}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 273.74it/s]
# [I 2022-04-23 14:45:32,939] Trial 16 finished with value: 0.17192151028892416 and parameters: {'max_depth': 3, 'splitter': 'random', 'criterion': 'squared_error', 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 21}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 222.05it/s]
# [I 2022-04-23 14:45:32,955] Trial 17 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 271.51it/s]
# [I 2022-04-23 14:45:33,143] Trial 18 finished with value: 0.1810978968393811 and parameters: {'max_depth': 3, 'splitter': 'random', 'criterion': 'friedman_mse', 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 21}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 214.10it/s]
# [I 2022-04-23 14:45:33,159] Trial 19 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 199.82it/s]
# [I 2022-04-23 14:45:33,177] Trial 20 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 316.18it/s]
# [I 2022-04-23 14:45:33,339] Trial 21 finished with value: 0.10015898897945967 and parameters: {'max_depth': 3, 'splitter': 'random', 'criterion': 'friedman_mse', 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 6}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:16,  2.92it/s]
# [I 2022-04-23 14:45:34,370] Trial 22 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:18,  2.54it/s]
# [I 2022-04-23 14:45:35,553] Trial 23 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:21<00:00,  2.28it/s]
# [I 2022-04-23 14:45:57,457] Trial 24 finished with value: 0.06398396382367408 and parameters: {'max_depth': 3, 'splitter': 'random', 'criterion': 'absolute_error', 'min_samples_split': 6, 'min_samples_leaf': 12, 'max_features': 6}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:19,  2.38it/s]
# [I 2022-04-23 14:45:58,721] Trial 25 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:23<00:00,  2.10it/s]
# [I 2022-04-23 14:46:22,498] Trial 26 finished with value: 0.06347213254327999 and parameters: {'max_depth': 3, 'splitter': 'random', 'criterion': 'absolute_error', 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 6}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:48<00:00,  1.04it/s]
# [I 2022-04-23 14:47:10,700] Trial 27 finished with value: 0.16965651300481394 and parameters: {'max_depth': 3, 'splitter': 'random', 'criterion': 'absolute_error', 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 21}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 181.00it/s]
# [I 2022-04-23 14:47:10,979] Trial 28 finished with value: 0.10856186039277733 and parameters: {'max_depth': 4, 'splitter': 'best', 'criterion': 'squared_error', 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 6}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 84.32it/s]
# [I 2022-04-23 14:47:11,576] Trial 29 finished with value: 0.09010357234431343 and parameters: {'max_depth': 4, 'splitter': 'best', 'criterion': 'squared_error', 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 21}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:00, 56.56it/s]
# [I 2022-04-23 14:47:11,632] Trial 30 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 162.02it/s]
# [I 2022-04-23 14:47:11,653] Trial 31 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:00<00:00, 58.20it/s]
# [I 2022-04-23 14:47:11,707] Trial 32 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 146.21it/s]
# [I 2022-04-23 14:47:11,732] Trial 33 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 162.03it/s]
# [I 2022-04-23 14:47:11,756] Trial 34 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 172.86it/s]
# [I 2022-04-23 14:47:12,049] Trial 35 finished with value: 0.12990460998003603 and parameters: {'max_depth': 4, 'splitter': 'best', 'criterion': 'friedman_mse', 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 6}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:02<00:38,  1.21it/s]
# [I 2022-04-23 14:47:14,533] Trial 36 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:02<00:34,  1.38it/s]
# [I 2022-04-23 14:47:16,711] Trial 37 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:05<01:21,  1.74s/it]
# [I 2022-04-23 14:47:21,944] Trial 38 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:02<00:37,  1.25it/s]
# [I 2022-04-23 14:47:24,338] Trial 39 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:08<00:00,  1.37s/it]
# [I 2022-04-23 14:48:33,032] Trial 40 finished with value: 0.16895913859353479 and parameters: {'max_depth': 4, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 6}. Best is trial 10 with value: 0.25273894722900436.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [03:19<00:00,  3.99s/it]
# [I 2022-04-23 14:51:52,602] Trial 41 finished with value: 0.32151179991312134 and parameters: {'max_depth': 4, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 21}. Best is trial 41 with value: 0.32151179991312134.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 237.33it/s]
# [I 2022-04-23 14:51:52,817] Trial 42 finished with value: 0.18274088006381883 and parameters: {'max_depth': 4, 'splitter': 'random', 'criterion': 'squared_error', 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 21}. Best is trial 41 with value: 0.32151179991312134.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 199.83it/s]
# [I 2022-04-23 14:51:52,835] Trial 43 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 222.03it/s]
# [I 2022-04-23 14:51:52,852] Trial 44 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 288.77it/s]
# [I 2022-04-23 14:51:53,029] Trial 45 finished with value: 0.1337410795501005 and parameters: {'max_depth': 4, 'splitter': 'random', 'criterion': 'squared_error', 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 6}. Best is trial 41 with value: 0.32151179991312134.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 206.72it/s]
# [I 2022-04-23 14:51:53,046] Trial 46 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 206.72it/s]
# [I 2022-04-23 14:51:53,063] Trial 47 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 296.48it/s]
# [I 2022-04-23 14:51:53,235] Trial 48 finished with value: 0.11961129905021903 and parameters: {'max_depth': 4, 'splitter': 'random', 'criterion': 'friedman_mse', 'min_samples_split': 6, 'min_samples_leaf': 12, 'max_features': 6}. Best is trial 41 with value: 0.32151179991312134.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                      | 3/50 [00:00<00:00, 193.38it/s]
# [I 2022-04-23 14:51:53,254] Trial 49 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 293.00it/s]
# [I 2022-04-23 14:51:53,429] Trial 50 finished with value: 0.12939450996171847 and parameters: {'max_depth': 4, 'splitter': 'random', 'criterion': 'friedman_mse', 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 6}. Best is trial 41 with value: 0.32151179991312134.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 234.54it/s]
# [I 2022-04-23 14:51:53,645] Trial 51 finished with value: 0.21253421617057994 and parameters: {'max_depth': 4, 'splitter': 'random', 'criterion': 'friedman_mse', 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 21}. Best is trial 41 with value: 0.32151179991312134.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:23,  1.97it/s]
# [I 2022-04-23 14:51:55,175] Trial 52 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
#   6%|███████▌                                                                                                                       | 3/50 [00:02<00:32,  1.45it/s]
# [I 2022-04-23 14:51:57,254] Trial 53 pruned.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:17<00:00,  2.89it/s]
# [I 2022-04-23 14:52:14,554] Trial 54 finished with value: 0.006044290153810242 and parameters: {'max_depth': 4, 'splitter': 'random', 'criterion': 'absolute_error', 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 2}. Best is trial 41 with value: 0.32151179991312134.
#   0%|                                                                                                                                       | 0/50 [00:00<?, ?it/s]C:\Users\Lyle\anaconda3\envs\tf27\lib\site-packages\optuna\distributions.py:359: FutureWarning: Samplers and other components in Optuna will assume that `step` is 1. `step` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:25<00:00,  1.96it/s]
# [I 2022-04-23 14:52:40,058] Trial 55 finished with value: 0.10728790883323513 and parameters: {'max_depth': 4, 'splitter': 'random', 'criterion': 'absolute_error', 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 6}. Best is trial 41 with value: 0.32151179991312134.
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:44<00:00,  6.89s/it]
# [I 2022-04-23 21:56:23,141] Trial 230 finished with value: 0.43145729268802296 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:43<00:00,  6.87s/it]
# [I 2022-04-23 22:02:06,653] Trial 231 finished with value: 0.43211197194762574 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:42<00:00,  6.84s/it]
# [I 2022-04-23 22:07:48,738] Trial 232 finished with value: 0.43101477103502484 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:42<00:00,  6.85s/it]
# [I 2022-04-23 22:13:31,055] Trial 233 finished with value: 0.43124738193962087 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:04<00:00,  6.10s/it]
# [I 2022-04-23 22:18:36,011] Trial 234 finished with value: 0.42957138790007143 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 31}. Best is trial 225 with value: 0.4330562858926929.
#   6%|███████▌                                                                                                                       | 3/50 [00:28<07:28,  9.55s/it]
# [I 2022-04-23 22:19:04,662] Trial 235 pruned.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [04:57<00:00,  5.94s/it]
# [I 2022-04-23 22:24:01,763] Trial 236 finished with value: 0.42640509555127926 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 30}. Best is trial 225 with value: 0.4330562858926929.
#   6%|███████▌                                                                                                                       | 3/50 [00:01<00:27,  1.68it/s]
# [I 2022-04-23 22:24:03,550] Trial 237 pruned.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:44<00:00,  6.88s/it]
# [I 2022-04-23 22:29:47,569] Trial 238 finished with value: 0.4290523110329449 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:15<00:00,  6.31s/it]
# [I 2022-04-23 22:35:02,924] Trial 239 finished with value: 0.4305476607985398 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 32}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [04:52<00:00,  5.85s/it]
# [I 2022-04-23 22:39:55,380] Trial 240 finished with value: 0.4145616599852704 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': 29}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:42<00:00,  6.85s/it]
# [I 2022-04-23 22:45:38,008] Trial 241 finished with value: 0.43106674614601187 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:43<00:00,  6.88s/it]
# [I 2022-04-23 22:51:21,901] Trial 242 finished with value: 0.42976555930691074 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:19<00:00,  6.40s/it]
# [I 2022-04-23 22:56:41,813] Trial 243 finished with value: 0.4316497026708491 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 32}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:44<00:00,  6.88s/it]
# [I 2022-04-23 23:02:25,970] Trial 244 finished with value: 0.4313148411626885 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:25<00:00,  6.52s/it]
# [I 2022-04-23 23:07:51,785] Trial 245 finished with value: 0.43288142336112445 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 33}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:18<00:00,  6.37s/it]
# [I 2022-04-23 23:13:10,275] Trial 246 finished with value: 0.43264900327486844 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 32}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [04:54<00:00,  5.88s/it]
# [I 2022-04-23 23:18:04,519] Trial 247 finished with value: 0.42723467339896104 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 29}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:22<00:00,  6.44s/it]
# [I 2022-04-23 23:23:26,709] Trial 248 finished with value: 0.4308122599797463 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 32}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [06:02<00:00,  7.26s/it]
# [I 2022-04-23 23:29:29,620] Trial 249 finished with value: 0.430355240781733 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 35}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:45<00:00,  6.91s/it]
# [I 2022-04-23 23:35:15,021] Trial 250 finished with value: 0.43143085940334813 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 33}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [06:04<00:00,  7.28s/it]
# [I 2022-04-23 23:41:19,264] Trial 251 finished with value: 0.4296673732791911 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 36}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:00<00:00,  6.02s/it]
# [I 2022-04-23 23:46:20,124] Trial 252 finished with value: 0.43130133364994167 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 29}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [02:45<00:00,  3.30s/it]
# [I 2022-04-23 23:49:05,199] Trial 253 finished with value: 0.3819039450543632 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 14}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [04:44<00:00,  5.69s/it]
# [I 2022-04-23 23:53:49,878] Trial 254 finished with value: 0.38826829658705747 and parameters: {'max_depth': 5, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 29}. Best is trial 225 with value: 0.4330562858926929.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:26<00:00,  6.52s/it]
# [I 2022-04-23 23:59:16,028] Trial 255 finished with value: 0.43368026269233484 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 5, 'min_samples_leaf': 11, 'max_features': 32}. Best is trial 255 with value: 0.43368026269233484.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:16<00:00,  6.34s/it]
# [I 2022-04-24 00:04:32,840] Trial 256 finished with value: 0.4307188835713568 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 5, 'min_samples_leaf': 11, 'max_features': 31}. Best is trial 255 with value: 0.43368026269233484.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:12<00:00,  6.25s/it]
# [I 2022-04-24 00:09:45,495] Trial 257 finished with value: 0.428116952659421 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 29}. Best is trial 255 with value: 0.43368026269233484.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:39<00:00,  6.79s/it]
# [I 2022-04-24 00:15:24,758] Trial 258 finished with value: 0.43156653632103337 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 5, 'min_samples_leaf': 11, 'max_features': 32}. Best is trial 255 with value: 0.43368026269233484.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:03<00:00,  6.06s/it]
# [I 2022-04-24 00:20:27,843] Trial 259 finished with value: 0.43062416040371654 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 5, 'min_samples_leaf': 14, 'max_features': 30}. Best is trial 255 with value: 0.43368026269233484.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:24<00:00,  6.49s/it]
# [I 2022-04-24 00:25:52,318] Trial 260 finished with value: 0.4292321342890745 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 2, 'min_samples_leaf': 11, 'max_features': 32}. Best is trial 255 with value: 0.43368026269233484.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [05:35<00:00,  6.71s/it]
# [I 2022-04-24 00:31:28,043] Trial 261 finished with value: 0.43113523389697034 and parameters: {'max_depth': 7, 'splitter': 'best', 'criterion': 'absolute_error', 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 33}. Best is trial 255 with value: 0.43368026269233484.
# Hyperparameter                          Datatype  \
# Maximum Tree Depth                       Integer
# Splitting Strategy                   Categorical
# Split Quality Criterion              Categorical
# Min. Samples to Split Internal Node      Integer
# Min. Samples to Split Leaf Node          Integer
# Features Considered During Split         Integer
#
# Hyperparameter                                                   Values/[Min, Max]  \
# Maximum Tree Depth                                                         [2, 10]
# Splitting Strategy                                                  [best, random]
# Split Quality Criterion              [squared_error, friedman_mse, absolute_error]
# Min. Samples to Split Internal Node                                        [2, 20]
# Min. Samples to Split Leaf Node                                            [1, 20]
# Features Considered During Split                                           [1, 39]
#
# Hyperparameter                      Log Scaling Gridpoint Count  \
# Maximum Tree Depth                        False               5
# Splitting Strategy                        False             N/A
# Split Quality Criterion                   False             N/A
# Min. Samples to Split Internal Node        True               3
# Min. Samples to Split Leaf Node            True               3
# Features Considered During Split           True               3
#
# Hyperparameter                           Best Value
# Maximum Tree Depth                                7
# Splitting Strategy                             best
# Split Quality Criterion              absolute_error
# Min. Samples to Split Internal Node               5
# Min. Samples to Split Leaf Node                  11
# Features Considered During Split                 32
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [10:37<00:00,  6.37s/it]
# R2: 0.4401697808634948
# MSE: 1.1558672580724147
# MAE: 0.29670175474346233
